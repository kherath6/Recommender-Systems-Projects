# %% [markdown]
# - Author: Kemil Herath
# - MIS 753: Independent Study, Fall 2021
#
# ## Collaborative filtering
# - For this project I'm using the yelp dataset:
# https://www.yelp.com/dataset
#
# - A subset of the businessness data and reviews data is used.
#
# #### Sources:
# - https://predictivehacks.com/item-based-collaborative-filtering-in-python/
# - https://chrisalbon.com/code/machine_learning/feature_engineering/select_best_number_of_components_in_tsvd/
# - https://realpython.com/build-recommendation-engine-collaborative-filtering/

# %%
## Load Libraries 
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns
import string 
from wordcloud import WordCloud

from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.corpus import stopwords
import re
import random
import nltk
from nltk.corpus import stopwords

import re 

pd.set_option('display.max_rows', None)
# Out:
# /Applications/anaconda3/lib/python3.7/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
# Load businesses data 
col_names = ['business_name', 'business_id', 'city', 'state', 'star_rating', 'service_categories']
business = pd.read_csv('Data/business.csv')
business.columns = col_names
business.head()
# Out:
#                    business_name             business_id       city state  \
# 0       Boruboru - Sandy Springs  kPiQ9kI_eP6LUob-Pv6AWg    Atlanta    GA
# 1  Smokey Bones Bar & Fire Grill  K-TMzK7eKQT4cAUoy_IlSw  Stoughton    MA
# 2                         Dugans  mjJI-DFchylyZHB0b3n2lA    Atlanta    GA
# 3                  China Station  3YsJCNhI4Vw7OtweFN622w     Boston    MA
# 4                 Ben Hill Grill  cOo7OHZinS8hn5P_-tFVKA    Atlanta    GA
#
#    star_rating                                 service_categories
# 0          4.5  Japanese, Sushi Bars, Food, Poke, Ramen, Resta...
# 1          2.5  Barbeque, Burgers, Restaurants, American (Trad...
# 2          2.5  Bars, American (Traditional), Restaurants, Nig...
# 3          4.0                               Chinese, Restaurants
# 4          4.5  Seafood, Fast Food, Vegan, American (Tradition...

# %%
business.shape
# Out:
# (34196, 6)

# %%
# Load reviews Data 
col_names = ['review_id', 'business_id', 'user_id', 'rating']
reviews = pd.read_csv('reviews.csv')
reviews.columns = col_names
reviews.head()
# Out:
#                 review_id             business_id                 user_id  \
# 0  J4a2TuhDasjn2k3wWtHZnQ  xGXzsc-hzam-VArK6eTvtw  RNm_RWkcd02Li2mKPRe7Eg
# 1  9vqwvFCBG3FBiHGmOHMmiA  DbXHNl890xSXNiyRczLWAg  XGkAG92TQ3MQUKGX9sLUhw
# 2  FdoBFTjXXMn4hVnJ59EtiQ  WQFn1A7-UAA4JT5YWiop_w  eLAYHxHUutiXswy-CfeiUw
# 3  ucFOnqgaV40oQ2YNyz5ddQ  KXCXaF5qimmtKKqnPc_LQA  JHXQEayrDHOWGexs0dCviA
# 4  GDgXjXSZCA1iNQWD7OHXfg  mOnesB4IF9j6-ZmHoOHOig  1RCRKuHgP3FskGUVnmFdxg
#
#    rating
# 0     1.0
# 1     5.0
# 2     1.0
# 3     1.0
# 4     4.0

# %%
reviews.shape
# Out:
# (250000, 4)

# %% [markdown]
# #### Take samples of the data for faster processing

# %%
## Take a random sample of reviews data for easier processing 
reviews1 = reviews.sample(frac=0.16, random_state=12)

# %%
reviews1.head()
# Out:
#                      review_id             business_id  \
# 109672  7O6ujyFXDW4DWf4LFOO1fQ  j-JGN1f_cN_20oePpRWXrw
# 143738  Cg75QYA8b4jypg6GDDn7vQ  OX01EqImVbTGWepgNPNsJA
# 180135  qSg3uobzatQaBBAwQZ57jQ  S7mL8gwckyeWuLGmE94kkw
# 248710  z7py0F2cQBJ0nwLzIaCjqA  EGsftsHMWmKF3mc2UQoQug
# 41081   ocfbk7Rl5TB2otquxlurIw  vQNe7TD_QDpGtGbkaAqi8Q
#
#                        user_id  rating
# 109672  8KpEEKNjzgHu_zWXA4-cbQ     5.0
# 143738  BQrLWECGBozqKaUVnv8TYw     5.0
# 180135  s7qFhPQgZq_po9ffh_Icpg     2.0
# 248710  4GUk6uuf-9QQIUxJYYPNBA     2.0
# 41081   LbfAaO0-15DunU_3qKGF4Q     5.0

# %%
reviews1.shape
# Out:
# (40000, 4)

# %%
## Take a random sampel of businessess data for easier processing 
business1 = business.sample(frac=0.15, random_state=42)

# %%
business1.shape
# Out:
# (5129, 6)

# %% [markdown]
# ### Data Processing/ Exploration

# %%
### Merge reviews data and businesses data
reviewsData = pd.merge(business1[['business_name', 'business_id']],
                       reviews1[['business_id','user_id','rating']],
                       on='business_id')

reviewsData.head()
# Out:
#             business_name             business_id                 user_id  \
# 0  Khob Khun Thai Cuisine  wTVzfhLOYUyd6wY9LJWC2w  dQyXVDO7JYKtgZfsV0xOhA
# 1  Khob Khun Thai Cuisine  wTVzfhLOYUyd6wY9LJWC2w  4jRbtVIieuBbSBJWDhP3jw
# 2  Khob Khun Thai Cuisine  wTVzfhLOYUyd6wY9LJWC2w  WzCU-7Vjvv2eTYx8f85U_A
# 3  Khob Khun Thai Cuisine  wTVzfhLOYUyd6wY9LJWC2w  Ff_K-dXlwSJwN-IVMpKuOw
# 4  Khob Khun Thai Cuisine  wTVzfhLOYUyd6wY9LJWC2w  GyZRi_VETkrHGQoRKa9gsQ
#
#    rating
# 0     5.0
# 1     5.0
# 2     4.0
# 3     5.0
# 4     1.0

# %%
reviewsData.shape
# Out:
# (3032, 4)

# %%
## Check which restaurent has most number of reviews 
reviewsData.groupby('business_name')['rating'].count().sort_values(ascending =False).head(10)
# Out:
# business_name
# Lechon                                                 128
# Barcelona Wine Bar South End                            81
# Tin Shed Garden Cafe                                    64
# FLIP burger boutique                                    63
# Santarpio's Pizza                                       62
# JINYA Ramen Bar - Austin                                52
# J & M Diner                                             49
# H&F Burger                                              48
# Cooper's Hawk Winery & Restaurant - Waterford Lakes     47
# Sushi Katana                                            47
# Name: rating, dtype: int64

# %% [markdown]
# - We can see that **Lechon** has the most reviews.

# %% [markdown]
# ### Utility matrix
# - U X R matrix where U: Users and R: Restaurants
# - The values will contain reviews given by each user for each restaurent

# %%
reviews_crosstab = reviewsData.pivot_table('rating', index='user_id', columns='business_name')

# %%
reviews_crosstab.head(10)
# Out:
# business_name           &pizza - Harvard Square  19th Hole  5 Star Pizza  \
# user_id
# -1CV3L7RAk34790wXVQu4g                      NaN        NaN           NaN
# -3s52C4zL_DHRK0ULG6qtg                      NaN        NaN           NaN
# -4RRsux7RIX19uBsVTSsMw                      NaN        NaN           NaN
# -5E2DVKUmSqpKPOWAL7sTg                      NaN        NaN           NaN
# -6t5bJFJne44N_E7lgdR6g                      NaN        NaN           NaN
# -9XyhOsyd8tOfgvFLGJfAQ                      NaN        NaN           NaN
# -A9ICz4e9hgrNK4-Fs3TmQ                      NaN        NaN           NaN
# -BCHgVhr-mx8iEBbphbTXw                      NaN        NaN           NaN
# -CUA8xL-9bCZN3nOi1e_Hw                      NaN        NaN           NaN
# -CvJZ3v4XxnzQAIZu5JvxQ                      NaN        NaN           NaN
#
# business_name           African Paradise Restaurant  \
# user_id
# -1CV3L7RAk34790wXVQu4g                          NaN
# -3s52C4zL_DHRK0ULG6qtg                          NaN
# -4RRsux7RIX19uBsVTSsMw                          NaN
# -5E2DVKUmSqpKPOWAL7sTg                          NaN
# -6t5bJFJne44N_E7lgdR6g                          NaN
# -9XyhOsyd8tOfgvFLGJfAQ                          NaN
# -A9ICz4e9hgrNK4-Fs3TmQ                          NaN
# -BCHgVhr-mx8iEBbphbTXw                          NaN
# -CUA8xL-9bCZN3nOi1e_Hw                          NaN
# -CvJZ3v4XxnzQAIZu5JvxQ                          NaN
#
# business_name           Alamo Drafthouse Cinema South Lamar  \
# user_id
# -1CV3L7RAk34790wXVQu4g                                  NaN
# -3s52C4zL_DHRK0ULG6qtg                                  NaN
# -4RRsux7RIX19uBsVTSsMw                                  NaN
# -5E2DVKUmSqpKPOWAL7sTg                                  NaN
# -6t5bJFJne44N_E7lgdR6g                                  NaN
# -9XyhOsyd8tOfgvFLGJfAQ                                  NaN
# -A9ICz4e9hgrNK4-Fs3TmQ                                  NaN
# -BCHgVhr-mx8iEBbphbTXw                                  NaN
# -CUA8xL-9bCZN3nOi1e_Hw                                  NaN
# -CvJZ3v4XxnzQAIZu5JvxQ                                  NaN
#
# business_name           American Fresh Beer Garden  Anaheim Produce  \
# user_id
# -1CV3L7RAk34790wXVQu4g                         NaN              NaN
# -3s52C4zL_DHRK0ULG6qtg                         NaN              NaN
# -4RRsux7RIX19uBsVTSsMw                         NaN              NaN
# -5E2DVKUmSqpKPOWAL7sTg                         NaN              NaN
# -6t5bJFJne44N_E7lgdR6g                         NaN              NaN
# -9XyhOsyd8tOfgvFLGJfAQ                         NaN              NaN
# -A9ICz4e9hgrNK4-Fs3TmQ                         NaN              NaN
# -BCHgVhr-mx8iEBbphbTXw                         NaN              NaN
# -CUA8xL-9bCZN3nOi1e_Hw                         NaN              NaN
# -CvJZ3v4XxnzQAIZu5JvxQ                         NaN              NaN
#
# business_name           Anna's Hand Cut Donuts  Arby's  Arepas Grill  ...  \
# user_id                                                               ...
# -1CV3L7RAk34790wXVQu4g                     NaN     NaN           NaN  ...
# -3s52C4zL_DHRK0ULG6qtg                     NaN     NaN           NaN  ...
# -4RRsux7RIX19uBsVTSsMw                     NaN     NaN           NaN  ...
# -5E2DVKUmSqpKPOWAL7sTg                     NaN     NaN           NaN  ...
# -6t5bJFJne44N_E7lgdR6g                     NaN     NaN           NaN  ...
# -9XyhOsyd8tOfgvFLGJfAQ                     NaN     NaN           NaN  ...
# -A9ICz4e9hgrNK4-Fs3TmQ                     NaN     NaN           NaN  ...
# -BCHgVhr-mx8iEBbphbTXw                     NaN     NaN           NaN  ...
# -CUA8xL-9bCZN3nOi1e_Hw                     NaN     NaN           NaN  ...
# -CvJZ3v4XxnzQAIZu5JvxQ                     NaN     NaN           NaN  ...
#
# business_name           Wok N' Kebab Asian Street Fare  X-Site Grill & Bistro  \
# user_id
# -1CV3L7RAk34790wXVQu4g                             NaN                    NaN
# -3s52C4zL_DHRK0ULG6qtg                             NaN                    NaN
# -4RRsux7RIX19uBsVTSsMw                             NaN                    NaN
# -5E2DVKUmSqpKPOWAL7sTg                             NaN                    NaN
# -6t5bJFJne44N_E7lgdR6g                             NaN                    NaN
# -9XyhOsyd8tOfgvFLGJfAQ                             NaN                    NaN
# -A9ICz4e9hgrNK4-Fs3TmQ                             NaN                    NaN
# -BCHgVhr-mx8iEBbphbTXw                             NaN                    NaN
# -CUA8xL-9bCZN3nOi1e_Hw                             NaN                    NaN
# -CvJZ3v4XxnzQAIZu5JvxQ                             NaN                    NaN
#
# business_name           Yan's China Bistro  Yoko Sushi   Yokohama Teppanyaki  \
# user_id
# -1CV3L7RAk34790wXVQu4g                 NaN          NaN                  NaN
# -3s52C4zL_DHRK0ULG6qtg                 NaN          NaN                  NaN
# -4RRsux7RIX19uBsVTSsMw                 NaN          NaN                  NaN
# -5E2DVKUmSqpKPOWAL7sTg                 NaN          NaN                  NaN
# -6t5bJFJne44N_E7lgdR6g                 NaN          NaN                  NaN
# -9XyhOsyd8tOfgvFLGJfAQ                 NaN          NaN                  NaN
# -A9ICz4e9hgrNK4-Fs3TmQ                 NaN          NaN                  NaN
# -BCHgVhr-mx8iEBbphbTXw                 NaN          NaN                  NaN
# -CUA8xL-9bCZN3nOi1e_Hw                 NaN          NaN                  NaN
# -CvJZ3v4XxnzQAIZu5JvxQ                 NaN          NaN                  NaN
#
# business_name           ZAZ  Zen Japanese Grill & Sushi Bar  \
# user_id
# -1CV3L7RAk34790wXVQu4g  NaN                             NaN
# -3s52C4zL_DHRK0ULG6qtg  NaN                             NaN
# -4RRsux7RIX19uBsVTSsMw  NaN                             NaN
# -5E2DVKUmSqpKPOWAL7sTg  NaN                             NaN
# -6t5bJFJne44N_E7lgdR6g  NaN                             NaN
# -9XyhOsyd8tOfgvFLGJfAQ  NaN                             NaN
# -A9ICz4e9hgrNK4-Fs3TmQ  NaN                             NaN
# -BCHgVhr-mx8iEBbphbTXw  NaN                             NaN
# -CUA8xL-9bCZN3nOi1e_Hw  NaN                             NaN
# -CvJZ3v4XxnzQAIZu5JvxQ  NaN                             NaN
#
# business_name           Zeus Greek Street Food  Zoup!  sandoitchi Pop Up
# user_id
# -1CV3L7RAk34790wXVQu4g                     NaN    NaN                NaN
# -3s52C4zL_DHRK0ULG6qtg                     NaN    NaN                NaN
# -4RRsux7RIX19uBsVTSsMw                     NaN    NaN                NaN
# -5E2DVKUmSqpKPOWAL7sTg                     NaN    NaN                NaN
# -6t5bJFJne44N_E7lgdR6g                     NaN    NaN                NaN
# -9XyhOsyd8tOfgvFLGJfAQ                     NaN    NaN                NaN
# -A9ICz4e9hgrNK4-Fs3TmQ                     NaN    NaN                NaN
# -BCHgVhr-mx8iEBbphbTXw                     NaN    NaN                NaN
# -CUA8xL-9bCZN3nOi1e_Hw                     NaN    NaN                NaN
# -CvJZ3v4XxnzQAIZu5JvxQ                     NaN    NaN                NaN
#
# [10 rows x 365 columns]

# %%
reviews_crosstab.shape
# Out:
# (3005, 365)

# %% [markdown]
# - This is a great example for a **sparse matrix (sparse data).**
# - Meaning this matrix contains a lot of null (0) values.
# - **This is a common occurrence in ratings data, and an obstecle to recommender systems.**

# %% [markdown]
# #### Fill null values with 0

# %%
reviews_crosstab = reviews_crosstab.fillna(0)

# %% [markdown]
# ### Model Based Colleborative Filtering
# - **Transpose** reviews_crosstab so that restaurents(items) are in rows are users are columns
# - Identify optimal number of componenets for SVD
# - Run truncated SVD on User and Restaurant matrix (reviews_crosstab)
# - Calculate the pearson correlation to identify similar users.

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import TruncatedSVD

# %% [markdown]
# ### 1. Transpose the utility matrix (reviews_crosstab)

# %%
reviews_crosstab.shape
# Out:
# (3005, 365)

# %%
# Convert X values to float
X = reviews_crosstab.astype(float)

# %%
X = reviews_crosstab.T
X.shape
# Out:
# (365, 3005)

# %%
X.head()
# Out:
# user_id                              -1CV3L7RAk34790wXVQu4g  \
# business_name
# &pizza - Harvard Square                                 0.0
# 19th Hole                                               0.0
# 5 Star Pizza                                            0.0
# African Paradise Restaurant                             0.0
# Alamo Drafthouse Cinema South Lamar                     0.0
#
# user_id                              -3s52C4zL_DHRK0ULG6qtg  \
# business_name
# &pizza - Harvard Square                                 0.0
# 19th Hole                                               0.0
# 5 Star Pizza                                            0.0
# African Paradise Restaurant                             0.0
# Alamo Drafthouse Cinema South Lamar                     0.0
#
# user_id                              -4RRsux7RIX19uBsVTSsMw  \
# business_name
# &pizza - Harvard Square                                 0.0
# 19th Hole                                               0.0
# 5 Star Pizza                                            0.0
# African Paradise Restaurant                             0.0
# Alamo Drafthouse Cinema South Lamar                     0.0
#
# user_id                              -5E2DVKUmSqpKPOWAL7sTg  \
# business_name
# &pizza - Harvard Square                                 0.0
# 19th Hole                                               0.0
# 5 Star Pizza                                            0.0
# African Paradise Restaurant                             0.0
# Alamo Drafthouse Cinema South Lamar                     0.0
#
# user_id                              -6t5bJFJne44N_E7lgdR6g  \
# business_name
# &pizza - Harvard Square                                 0.0
# 19th Hole                                               0.0
# 5 Star Pizza                                            0.0
# African Paradise Restaurant                             0.0
# Alamo Drafthouse Cinema South Lamar                     0.0
#
# user_id                              -9XyhOsyd8tOfgvFLGJfAQ  \
# business_name
# &pizza - Harvard Square                                 0.0
# 19th Hole                                               0.0
# 5 Star Pizza                                            0.0
# African Paradise Restaurant                             0.0
# Alamo Drafthouse Cinema South Lamar                     0.0
#
# user_id                              -A9ICz4e9hgrNK4-Fs3TmQ  \
# business_name
# &pizza - Harvard Square                                 0.0
# 19th Hole                                               0.0
# 5 Star Pizza                                            0.0
# African Paradise Restaurant                             0.0
# Alamo Drafthouse Cinema South Lamar                     0.0
#
# user_id                              -BCHgVhr-mx8iEBbphbTXw  \
# business_name
# &pizza - Harvard Square                                 0.0
# 19th Hole                                               0.0
# 5 Star Pizza                                            0.0
# African Paradise Restaurant                             0.0
# Alamo Drafthouse Cinema South Lamar                     0.0
#
# user_id                              -CUA8xL-9bCZN3nOi1e_Hw  \
# business_name
# &pizza - Harvard Square                                 0.0
# 19th Hole                                               0.0
# 5 Star Pizza                                            0.0
# African Paradise Restaurant                             0.0
# Alamo Drafthouse Cinema South Lamar                     0.0
#
# user_id                              -CvJZ3v4XxnzQAIZu5JvxQ  ...  \
# business_name                                                ...
# &pizza - Harvard Square                                 0.0  ...
# 19th Hole                                               0.0  ...
# 5 Star Pizza                                            0.0  ...
# African Paradise Restaurant                             0.0  ...
# Alamo Drafthouse Cinema South Lamar                     0.0  ...
#
# user_id                              zpwbkEZPuJ5kpYULdEuRiw  \
# business_name
# &pizza - Harvard Square                                 0.0
# 19th Hole                                               0.0
# 5 Star Pizza                                            0.0
# African Paradise Restaurant                             0.0
# Alamo Drafthouse Cinema South Lamar                     0.0
#
# user_id                              zrbk3Xzx6V3s4fCOvNBEKw  \
# business_name
# &pizza - Harvard Square                                 0.0
# 19th Hole                                               0.0
# 5 Star Pizza                                            0.0
# African Paradise Restaurant                             0.0
# Alamo Drafthouse Cinema South Lamar                     0.0
#
# user_id                              zs4NnxnKBKTCf-DlLXHyzg  \
# business_name
# &pizza - Harvard Square                                 0.0
# 19th Hole                                               0.0
# 5 Star Pizza                                            0.0
# African Paradise Restaurant                             0.0
# Alamo Drafthouse Cinema South Lamar                     0.0
#
# user_id                              zsUMstOI2PIGkPsc58VZIw  \
# business_name
# &pizza - Harvard Square                                 0.0
# 19th Hole                                               0.0
# 5 Star Pizza                                            0.0
# African Paradise Restaurant                             0.0
# Alamo Drafthouse Cinema South Lamar                     0.0
#
# user_id                              ztD-vr_Q2iBEw7g9qLRceQ  \
# business_name
# &pizza - Harvard Square                                 0.0
# 19th Hole                                               0.0
# 5 Star Pizza                                            0.0
# African Paradise Restaurant                             0.0
# Alamo Drafthouse Cinema South Lamar                     0.0
#
# user_id                              zuJizFaUq59eywOjN5cdxw  \
# business_name
# &pizza - Harvard Square                                 0.0
# 19th Hole                                               0.0
# 5 Star Pizza                                            0.0
# African Paradise Restaurant                             0.0
# Alamo Drafthouse Cinema South Lamar                     0.0
#
# user_id                              zvTHuymw0LCHBcVEt5WHsA  \
# business_name
# &pizza - Harvard Square                                 0.0
# 19th Hole                                               0.0
# 5 Star Pizza                                            0.0
# African Paradise Restaurant                             0.0
# Alamo Drafthouse Cinema South Lamar                     0.0
#
# user_id                              zwsfGSYBHnssi6mDYXepTw  \
# business_name
# &pizza - Harvard Square                                 0.0
# 19th Hole                                               0.0
# 5 Star Pizza                                            0.0
# African Paradise Restaurant                             0.0
# Alamo Drafthouse Cinema South Lamar                     0.0
#
# user_id                              zxSTe_VEZPK8e2PnkwgcGA  \
# business_name
# &pizza - Harvard Square                                 0.0
# 19th Hole                                               0.0
# 5 Star Pizza                                            0.0
# African Paradise Restaurant                             0.0
# Alamo Drafthouse Cinema South Lamar                     0.0
#
# user_id                              zzdi0RIbc21HMJYIpBg8lw
# business_name
# &pizza - Harvard Square                                 0.0
# 19th Hole                                               0.0
# 5 Star Pizza                                            0.0
# African Paradise Restaurant                             0.0
# Alamo Drafthouse Cinema South Lamar                     0.0
#
# [5 rows x 3005 columns]

# %% [markdown]
# ### 2. Identify the optimal number of components for SVD

# %%
X.shape
# Out:
# (365, 3005)

# %%
compSVD = TruncatedSVD(n_components=X.shape[1]-1)

# %%
compSVD.fit(X)
# Out:
# TruncatedSVD(n_components=3004)

# %%
## Create a list of explanied variances 
svd_var_ratios = compSVD.explained_variance_ratio_

# %%
## Create a function to get n_componenets that exceeds the defined threshold
def select_n_components(var_ratio, goal_var: float) -> int:
    # Set initial variance explained so far
    total_variance = 0.0
    
    # Set initial number of features
    n_components = 0
    
    # For the explained variance of each feature:
    for explained_variance in var_ratio:
        
        # Add the explained variance to the total
        total_variance += explained_variance
        
        # Add one to the number of components
        n_components += 1
        
        # If we reach our goal level of explained variance
        if total_variance >= goal_var:
            # End the loop
            break
            
    # Return the number of components
    return n_components

# %%
# Get the n_components using the function 
n_comp = select_n_components(svd_var_ratios, 0.95)

# %%
n_comp
# Out:
# 231

# %%
n_comp/X.shape[1]
# Out:
# 0.07687188019966722

# %% [markdown]
# ### 3. Run SVD using n_components

# %%
X.shape
# Out:
# (365, 3005)

# %%
SVD = TruncatedSVD(n_components=n_comp, random_state=12)
resultant_matrix = SVD.fit_transform(X)
resultant_matrix.shape
# Out:
# (365, 231)

# %% [markdown]
# ### 4. Create correlation matrix using Pearson Correaltion

# %%
corr_mat = np.corrcoef(resultant_matrix)
corr_mat.shape
# Out:
# (365, 365)

# %% [markdown]
# #### Find indexes of restaurents to be recommended

# %%
## Check which restaurent has most number of reviews 
reviewsData.groupby('business_name')['rating'].count().sort_values(ascending =False)[:100]
# Out:
# business_name
# Lechon                                                 128
# Barcelona Wine Bar South End                            81
# Tin Shed Garden Cafe                                    64
# FLIP burger boutique                                    63
# Santarpio's Pizza                                       62
# JINYA Ramen Bar - Austin                                52
# J & M Diner                                             49
# H&F Burger                                              48
# Cooper's Hawk Winery & Restaurant - Waterford Lakes     47
# Sushi Katana                                            47
# Westgate Lakes Resort and Spa                           44
# Marutama Ramen                                          43
# Roaring Fork                                            42
# The COOP: A Southern Affair                             37
# Heo Eatery                                              37
# Shaking Crab - Newton                                   33
# Coquine                                                 31
# Caffè Nero                                              30
# Truva Turkish Kitchen                                   30
# Blaze Pizza                                             29
# Pammy's                                                 28
# Bluetop                                                 27
# Miller's Ale House - Orlando                            26
# Southland Whiskey Kitchen                               26
# Catch 122                                               25
# The Breakfast Club                                      25
# Carlo's Cucina Italiana                                 25
# Select Oyster Bar                                       25
# Maenam                                                  25
# Zeus Greek Street Food                                  24
# Parish Cafe and Bar                                     24
# Le's Vietnamese Resturant                               23
# Black Bear Diner                                        23
# Alamo Drafthouse Cinema South Lamar                     23
# Granny's Tacos                                          22
# City Barbeque                                           22
# Mattie's                                                21
# The Crepevine                                           21
# Five Horses Tavern                                      21
# Slim & Husky's Pizza Beeria                             20
# McMenamins on the Columbia                              20
# Tortas El Rey                                           20
# Locale                                                  19
# Boston Lobster Feast                                    19
# Rimsky-Korsakoffee House                                18
# Momo N Curry                                            18
# South Village Grille                                    17
# Red Robin Gourmet Burgers and Brews                     17
# Bhuna                                                   17
# Kyoto Sushi and Grill                                   16
# Bobby & Jack’s Memphis Barbecue                         16
# The One Sushi +                                         16
# Casa del Pollo                                          15
# Cilantro's Taqueria                                     15
# Champions                                               15
# Les Faux Bourgeois                                      15
# Sapporo Ramen                                           15
# BJ's Restaurant & Brewhouse                             15
# Bubble World                                            14
# Texican Cafe - Manchaca                                 14
# Johnny Carino's                                         13
# Wingstop                                                13
# Khob Khun Thai Cuisine                                  13
# Karver Sandwich Bar                                     13
# Tucci's                                                 13
# Java Cats Cafe                                          13
# Mark's Jamaican Bar & Grill                             13
# House of Blues Boston- Music Venue                      12
# Bakery Lorraine                                         12
# Wendy's                                                 12
# New Kings Buffet                                        12
# Arepazo Tapas & Wine                                    11
# Expatriate                                              11
# Martsa On Elm                                           11
# Zen Japanese Grill & Sushi Bar                          11
# Sissy K's                                               10
# Sorelle                                                 10
# Fuddruckers                                             10
# Ray's Fish & Chips                                      10
# License No. 1                                           10
# Pho Star in Vancouver                                   10
# Olive Garden Italian Restaurant                         10
# Guacamole Mexican Grill                                 10
# Marinepolis Sushi Land                                   9
# Jimmy Hula's                                             9
# Pio Pio Ocoee                                            9
# Kongee Dinesty                                           9
# Fado Pub & Kitchen                                       9
# Panera Bread                                             9
# Golden Swan Restaurant                                   9
# Koi Hot Pot                                              9
# Embilta Café & Restaurant Ethiopian Cuisine              9
# Olive Bistro Midtown                                     9
# LongHorn Steakhouse                                      9
# Vatica Indian Cuisine                                    9
# Burger King                                              9
# Chili's                                                  9
# Uptown Deli and Brew                                     9
# The Thirsty Topher                                       8
# Sulmida Dessert Cafe                                     8
# Name: rating, dtype: int64

# %% [markdown]
# ### 5. Receommendations

# %%
col_idx = reviews_crosstab.columns.get_loc("FLIP burger boutique")
specific_corr = corr_mat[col_idx]
pd.DataFrame({'Correlation': specific_corr, "Restaurant":reviews_crosstab.columns}).sort_values(
                                                                    'Correlation', ascending=False).head(10)
# Out:
#      Correlation            Restaurant
# 102     1.000000  FLIP burger boutique
# 364     0.012086     sandoitchi Pop Up
# 287     0.008818     Sunny Street Cafe
# 9       0.008106          Arepas Grill
# 358     0.008019           Yoko Sushi
# 139     0.007435                  IHOP
# 135     0.007307        Hot Spot Pizza
# 255     0.007076  Relish Burger Bistro
# 243     0.007042    Pizza Peddler Deli
# 346     0.006640          Waffle House

# %%
col_idx = reviews_crosstab.columns.get_loc("Lechon")
specific_corr = corr_mat[col_idx]
pd.DataFrame({'Correlation': specific_corr, "Restaurant":reviews_crosstab.columns}).sort_values(
                                                                    'Correlation', ascending=False).head(10)
# Out:
#      Correlation            Restaurant
# 172     1.000000                Lechon
# 364     0.012086     sandoitchi Pop Up
# 287     0.008818     Sunny Street Cafe
# 9       0.008106          Arepas Grill
# 358     0.008019           Yoko Sushi
# 139     0.007435                  IHOP
# 135     0.007307        Hot Spot Pizza
# 255     0.007076  Relish Burger Bistro
# 243     0.007042    Pizza Peddler Deli
# 346     0.006640          Waffle House

# %%
business.loc[business.business_name == "Lechon"]
# Out:
#       business_name             business_id      city state  star_rating  \
# 25749        Lechon  eUbq0uNxRlXQ6sy7phM7yA  Portland    OR          4.5
#
#                                       service_categories
# 25749  Tapas Bars, Restaurants, Cocktail Bars, Nightl...

# %%
col_idx = reviews_crosstab.columns.get_loc("Marutama Ramen")
specific_corr = corr_mat[col_idx]
pd.DataFrame({'Correlation': specific_corr, "Restaurant":reviews_crosstab.columns}).sort_values(
                                                                    'Correlation', ascending=False).head(10)
# Out:
#      Correlation          Restaurant
# 189     1.000000      Marutama Ramen
# 134     0.090809          Hong Sushi
# 364     0.012067   sandoitchi Pop Up
# 287     0.009975   Sunny Street Cafe
# 358     0.009168         Yoko Sushi
# 139     0.009054                IHOP
# 9       0.008537        Arepas Grill
# 243     0.007979  Pizza Peddler Deli
# 110     0.007490             Foodoko
# 346     0.007384        Waffle House
